# %%
import os
import pandas as pd

# %%
import spacy
model = spacy.load("en_core_web_lg")

# %%
path_clinical = "/Users/johannesalkofer/Downloads/pdf_to_text/schizophrenia_output_txt"
path_control = "/Users/johannesalkofer/Downloads/pdf_to_text/one_folder_control_output_txt"

# %%
# defines seperator constant

SEPARATOR = "=================================================="

# collects file names and their content

data = []
for filename in os.listdir(path_clinical):
    if filename.endswith(".txt"):
        file_path = os.path.join(path_clinical, filename)
        with open(file_path, "r", encoding="utf-8") as f:
            full_text = f.read()
        
        # splits the text and only keeps the part after the separator
        # if the separator isn't found, it defaults to the full text

        parts = full_text.split(SEPARATOR)
        clean_text = parts[-1].strip() 
        
        data.append({"filename": filename, "text": clean_text})

# convert to DataFrame

clinical = pd.DataFrame(data)

# %%
# defines separator constant
SEPARATOR = "=================================================="

# collects file names and their content

data = []
for filename in os.listdir(path_control):
    if filename.endswith(".txt"):
        file_path = os.path.join(path_control, filename)
        with open(file_path, "r", encoding="utf-8") as f:
            full_text = f.read()
        
        # splits the text and keeps only the part after the separator
        # if the separator isn't found, it defaults to the full text

        parts = full_text.split(SEPARATOR)
        clean_text = parts[-1].strip() 
        
        data.append({"filename": filename, "text": clean_text})

# convert to DataFrame
control = pd.DataFrame(data)

# %%
control
# Out:
#                                              filename  \
# 0   2025-12-19_personal_account_from_shame_to_stor...
# 1   2025-12-19_personal_account_art_heals_combatin...
# 2   2025-12-19_personal_account_the_pendulum_of_my...
# 3   2025-12-19_personal_account_dreaming_beyond_my...
# 4     2025-12-19_personal_account_doing_it_afraid.txt
# 5   2025-12-19_personal_account_an_unrecognized_sy...
# 6   2025-12-19_personal_account_from_darkness_to_l...
# 7   2025-12-19_personal_account_my_journey_through...
# 8   2025-12-19_personal_account_from_shame_to_stor...
# 9   2025-12-19_personal_account_teetering_on_a_tig...
# 10  2025-12-19_personal_account_diagnosed_at_38_li...
# 11  2025-12-19_personal_account_harm_ocd_made_me_a...
# 12  2025-12-19_personal_account_my_obsessive_comed...
# 13  2025-12-19_personal_account_fearless_living_my...
# 14  2025-12-19_personal_account_content_with_a_cau...
#
#                                                  text
# 0   I have spent countless nights trapped in my ow...
# 1   From an early age, I struggled with unrealisti...
# 2   If there was ever a chance I would’ve been tol...
# 3   I couldn’t dream. Not in the sleeping sense bu...
# 4   The first notable experience that I had with a...
# 5   Bipolar rage is a waking nightmare for the per...
# 6   Early Childhood\n\nI encountered my first obse...
# 7   For most of my life, I lived under the weight ...
# 8   I sat across from the psychiatrist at my unive...
# 9   Have you ever seen a person walking on a tight...
# 10  I have Bipolar 1 Disorder. I had a manic episo...
# 11  My OCD tells me that I am a bad mom. Sometimes...
# 12  You know what I love about people with obsessi...
# 13  I've battled severe anxiety for over 15 years....
# 14  Five years ago, I faced one of the toughest de...

# %%
clinical
# Out:
#                                              filename  \
# 0   2025-12-18_personal_account_sharing_my_paranoi...
# 1    2025-12-18_personal_account_exposure_therapy.txt
# 2   2025-12-18_personal_account_creativity_and_sch...
# 3   2025-12-18_personal_account_my_experience_with...
# 4   2025-12-18_personal_account_recovery_champions...
# 5   2025-12-18_personal_account_schizophrenia_and_...
# 6   2025-12-18_personal_account_the_onset_of_my_sc...
# 7   2025-12-18_personal_account_a_psychotic_experi...
# 8   2025-12-18_personal_account_day_to_day_living_...
# 9   2025-12-18_personal_account_my_49-year_recover...
# 10  2025-12-18_personal_account_schizophrenia_and_...
# 11  2025-12-18_personal_account_an_evil_cradling_f...
# 12  2025-12-18_personal_account_a_kind_gesture_in_...
# 13            2025-12-18_personal_account_bad_day.txt
# 14  2025-12-18_personal_account_the_quest_for_real...
#
#                                                  text
# 0   Last night my internet went down. I tried disc...
# 1   During both my schizoaffective disorder episod...
# 2   When I was a small child, I worked on fistfuls...
# 3   My experience with psychiatric services has be...
# 4   Having a mental health problem can be a fright...
# 5   When I had my first psychotic episode, I was s...
# 6   My name is Leif Gregersen and I have been diag...
# 7   It’s been roughly one month since I had a suic...
# 8   When I was initially diagnosed with schizophre...
# 9   Although I was a very insecure girl and young ...
# 10  When I was psychotic, I believed incredible th...
# 11  When I found out I was pregnant for the fourth...
# 12  The psych ward can be an unbearably lonely pla...
# 13  When I have a bad day or even a bad night, I t...
# 14  Becoming aware of delusions in one’s mind is a...

# %%
clinical["group"] = "scz"
control["group"] = "hc"

# %%
clinical
# Out:
#                                              filename  \
# 0   2025-12-18_personal_account_sharing_my_paranoi...
# 1    2025-12-18_personal_account_exposure_therapy.txt
# 2   2025-12-18_personal_account_creativity_and_sch...
# 3   2025-12-18_personal_account_my_experience_with...
# 4   2025-12-18_personal_account_recovery_champions...
# 5   2025-12-18_personal_account_schizophrenia_and_...
# 6   2025-12-18_personal_account_the_onset_of_my_sc...
# 7   2025-12-18_personal_account_a_psychotic_experi...
# 8   2025-12-18_personal_account_day_to_day_living_...
# 9   2025-12-18_personal_account_my_49-year_recover...
# 10  2025-12-18_personal_account_schizophrenia_and_...
# 11  2025-12-18_personal_account_an_evil_cradling_f...
# 12  2025-12-18_personal_account_a_kind_gesture_in_...
# 13            2025-12-18_personal_account_bad_day.txt
# 14  2025-12-18_personal_account_the_quest_for_real...
#
#                                                  text group
# 0   Last night my internet went down. I tried disc...   scz
# 1   During both my schizoaffective disorder episod...   scz
# 2   When I was a small child, I worked on fistfuls...   scz
# 3   My experience with psychiatric services has be...   scz
# 4   Having a mental health problem can be a fright...   scz
# 5   When I had my first psychotic episode, I was s...   scz
# 6   My name is Leif Gregersen and I have been diag...   scz
# 7   It’s been roughly one month since I had a suic...   scz
# 8   When I was initially diagnosed with schizophre...   scz
# 9   Although I was a very insecure girl and young ...   scz
# 10  When I was psychotic, I believed incredible th...   scz
# 11  When I found out I was pregnant for the fourth...   scz
# 12  The psych ward can be an unbearably lonely pla...   scz
# 13  When I have a bad day or even a bad night, I t...   scz
# 14  Becoming aware of delusions in one’s mind is a...   scz

# %%
df = pd.concat([clinical, control], axis=0)

# %%
df = df.replace("\n", " ", regex=True)

# %%
# adds custom stopwords

custom_stops = {"er", "erm", "oh", "yeah", "mm", "mhm", "y"}

for w in custom_stops:
    model.Defaults.stop_words.add(w)
    model.vocab[w].is_stop = True

# %%
model.Defaults.stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'er',
#  'erm',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'mhm',
#  'might',
#  'mine',
#  'mm',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'oh',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'y',
#  'yeah',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
def get_cleaned_tokens(text):
    spacy_text = model(text)
    list_of_tokens = [
        token.text
        for token in spacy_text
        if (not token.is_punct)
        and (not token.is_stop)
        and token.text.strip()              # removes whitespace-only tokens
    ]
    return list_of_tokens

def get_chunks(list_of_tokens):
    chunks = [list_of_tokens[i:i+10] for i in range(0, len(list_of_tokens), 10)]
    return chunks

# %%
get_cleaned_tokens("hello world how are you doing")
# Out:
# ['hello', 'world']

# %%
df["list_tokens"] = df["text"].apply(get_cleaned_tokens)

# %%
df
# Out:
#                                              filename  \
# 0   2025-12-18_personal_account_sharing_my_paranoi...
# 1    2025-12-18_personal_account_exposure_therapy.txt
# 2   2025-12-18_personal_account_creativity_and_sch...
# 3   2025-12-18_personal_account_my_experience_with...
# 4   2025-12-18_personal_account_recovery_champions...
# 5   2025-12-18_personal_account_schizophrenia_and_...
# 6   2025-12-18_personal_account_the_onset_of_my_sc...
# 7   2025-12-18_personal_account_a_psychotic_experi...
# 8   2025-12-18_personal_account_day_to_day_living_...
# 9   2025-12-18_personal_account_my_49-year_recover...
# 10  2025-12-18_personal_account_schizophrenia_and_...
# 11  2025-12-18_personal_account_an_evil_cradling_f...
# 12  2025-12-18_personal_account_a_kind_gesture_in_...
# 13            2025-12-18_personal_account_bad_day.txt
# 14  2025-12-18_personal_account_the_quest_for_real...
# 0   2025-12-19_personal_account_from_shame_to_stor...
# 1   2025-12-19_personal_account_art_heals_combatin...
# 2   2025-12-19_personal_account_the_pendulum_of_my...
# 3   2025-12-19_personal_account_dreaming_beyond_my...
# 4     2025-12-19_personal_account_doing_it_afraid.txt
# 5   2025-12-19_personal_account_an_unrecognized_sy...
# 6   2025-12-19_personal_account_from_darkness_to_l...
# 7   2025-12-19_personal_account_my_journey_through...
# 8   2025-12-19_personal_account_from_shame_to_stor...
# 9   2025-12-19_personal_account_teetering_on_a_tig...
# 10  2025-12-19_personal_account_diagnosed_at_38_li...
# 11  2025-12-19_personal_account_harm_ocd_made_me_a...
# 12  2025-12-19_personal_account_my_obsessive_comed...
# 13  2025-12-19_personal_account_fearless_living_my...
# 14  2025-12-19_personal_account_content_with_a_cau...
#
#                                                  text group  \
# 0   Last night my internet went down. I tried disc...   scz
# 1   During both my schizoaffective disorder episod...   scz
# 2   When I was a small child, I worked on fistfuls...   scz
# 3   My experience with psychiatric services has be...   scz
# 4   Having a mental health problem can be a fright...   scz
# 5   When I had my first psychotic episode, I was s...   scz
# 6   My name is Leif Gregersen and I have been diag...   scz
# 7   It’s been roughly one month since I had a suic...   scz
# 8   When I was initially diagnosed with schizophre...   scz
# 9   Although I was a very insecure girl and young ...   scz
# 10  When I was psychotic, I believed incredible th...   scz
# 11  When I found out I was pregnant for the fourth...   scz
# 12  The psych ward can be an unbearably lonely pla...   scz
# 13  When I have a bad day or even a bad night, I t...   scz
# 14  Becoming aware of delusions in one’s mind is a...   scz
# 0   I have spent countless nights trapped in my ow...    hc
# 1   From an early age, I struggled with unrealisti...    hc
# 2   If there was ever a chance I would’ve been tol...    hc
# 3   I couldn’t dream. Not in the sleeping sense bu...    hc
# 4   The first notable experience that I had with a...    hc
# 5   Bipolar rage is a waking nightmare for the per...    hc
# 6   Early Childhood  I encountered my first obsess...    hc
# 7   For most of my life, I lived under the weight ...    hc
# 8   I sat across from the psychiatrist at my unive...    hc
# 9   Have you ever seen a person walking on a tight...    hc
# 10  I have Bipolar 1 Disorder. I had a manic episo...    hc
# 11  My OCD tells me that I am a bad mom. Sometimes...    hc
# 12  You know what I love about people with obsessi...    hc
# 13  I've battled severe anxiety for over 15 years....    hc
# 14  Five years ago, I faced one of the toughest de...    hc
#
#                                           list_tokens
# 0   [night, internet, went, tried, disconnecting, ...
# 1   [schizoaffective, disorder, episodes, obsessiv...
# 2   [small, child, worked, fistfuls, clay, grandfa...
# 3   [experience, psychiatric, services, bad, good,...
# 4   [Having, mental, health, problem, frightening,...
# 5   [psychotic, episode, sick, seven, long, months...
# 6   [Leif, Gregersen, diagnosed, schizoaffective, ...
# 7   [roughly, month, suicide, attempt, trying, hol...
# 8   [initially, diagnosed, schizophrenia, meds, ho...
# 9   [insecure, girl, young, woman, managed, functi...
# 10  [psychotic, believed, incredible, things, base...
# 11  [found, pregnant, fourth, time, worried, affor...
# 12  [psych, ward, unbearably, lonely, place, thoug...
# 13  [bad, day, bad, night, try, reduce, triggers, ...
# 14  [aware, delusions, mind, complex, process, hap...
# 0   [spent, countless, nights, trapped, mind, slee...
# 1   [early, age, struggled, unrealistic, fears, wo...
# 2   [chance, told, junior, year, sitting, college,...
# 3   [dream, sleeping, sense, way, people, humans, ...
# 4   [notable, experience, anxiety, occurred, 18, y...
# 5   [Bipolar, rage, waking, nightmare, person, gri...
# 6   [Early, Childhood, encountered, obsessive, tho...
# 7   [life, lived, weight, enoughness, matter, achi...
# 8   [sat, psychiatrist, university, health, center...
# 9   [seen, person, walking, tightrope, suspended, ...
# 10  [Bipolar, 1, Disorder, manic, episode, years, ...
# 11  [OCD, tells, bad, mom, self, doubt, actually, ...
# 12  [know, love, people, obsessive, compulsive, di...
# 13  [battled, severe, anxiety, 15, years, journey,...
# 14  [years, ago, faced, toughest, decisions, life,...

# %%
df["list_of_cunks"] = df["list_tokens"].apply(get_chunks)

# %%
df.iloc[0,-1]
# Out:
# [['night',
#   'internet',
#   'went',
#   'tried',
#   'disconnecting',
#   'reconnecting',
#   'clicked',
#   'diagnostic',
#   'know',
#   'DSN'],
#  ['schizo-',
#   'phrenia',
#   'entered',
#   'mind',
#   'acquaintance',
#   'met',
#   'neighborhood',
#   'looking',
#   'fiancée',
#   'shoulder'],
#  ['hacking',
#   'computer',
#   'messing',
#   'internet',
#   'entered',
#   'mind',
#   'thought',
#   'called',
#   'stupid',
#   'wanted'],
#  ['prove',
#   'schizophrenia',
#   'control',
#   'suddenly',
#   'pops',
#   'head',
#   'experience',
#   'learned',
#   'react',
#   'false'],
#  ['thoughts',
#   'paranoia',
#   'ordeal',
#   'internet',
#   'called',
#   'mom',
#   'tried',
#   'help',
#   'problem',
#   'advised'],
#  ['internet',
#   'provider',
#   'called',
#   're-',
#   'corded',
#   'message',
#   'told',
#   'internet',
#   'neighborhood',
#   'problem'],
#  ['solved',
#   'neighbor',
#   'paranoid',
#   'thinking',
#   'schiz-',
#   'ophrenia',
#   'control',
#   'thinking',
#   'enters',
#   'exits'],
#  ['mind',
#   'specific',
#   'delusions',
#   'far',
#   'acquaintance',
#   'messing',
#   'internet',
#   're-',
#   'member',
#   'react'],
#  ['pictures',
#   'paranoia',
#   'mind',
#   'important',
#   'react',
#   'thoughts',
#   'loud',
#   'following',
#   'day',
#   'internet'],
#  ['re-',
#   'stored',
#   'thing',
#   'sure',
#   'thoughts',
#   'night',
#   'racing',
#   'glad',
#   'able',
#   'melatonin'],
#  ['sleep',
#   'following',
#   'evening',
#   'got',
#   'text',
#   'ac-',
#   'quaintance',
#   'mind',
#   'messing',
#   'internet'],
#  ['text',
#   'said',
#   'big',
#   'trip',
#   'grocery',
#   'store',
#   'needed',
#   'help',
#   'bringing',
#   'groceries'],
#  ['messed',
#   'night',
#   'think',
#   'asking',
#   'neighborly',
#   'favors',
#   'Regretfully',
#   'control',
#   'paranoid',
#   'thoughts'],
#  ['refuse',
#   'react',
#   'loud',
#   'important',
#   'realize',
#   'pass',
#   'compliant',
#   'medication',
#   'appoint-',
#   'ments'],
#  ['psychiatrist',
#   'Chances',
#   'tell',
#   'psychiatrist',
#   'experience',
#   'wish',
#   'tell',
#   'neighbor',
#   'wish',
#   'tell'],
#  ['neighbor',
#   'example',
#   'like',
#   'living',
#   'schizophrenia',
#   'given',
#   'moment',
#   'stigma',
#   'today',
#   'world'],
#  ['matter',
#   'fact',
#   'language',
#   'living',
#   'schizophrenia',
#   'accepted',
#   'feel',
#   'like',
#   'loud',
#   'choose'],
#  ['written',
#   'word',
#   'want',
#   'people',
#   'experience',
#   'kind',
#   'racing',
#   'thoughts',
#   'paranoia',
#   'know'],
#  ['want',
#   'loved',
#   'ones',
#   'know',
#   'like',
#   'person',
#   'living',
#   'schizophrenia',
#   'Maybe',
#   'day'],
#  ['talk', 'loud', 'schizophrenia', 'like', 'condition']]

# %%
df_exploded = df.explode("list_of_cunks").reset_index(drop=True)

# %%
df_exploded
# Out:
#                                                filename  \
# 0     2025-12-18_personal_account_sharing_my_paranoi...
# 1     2025-12-18_personal_account_sharing_my_paranoi...
# 2     2025-12-18_personal_account_sharing_my_paranoi...
# 3     2025-12-18_personal_account_sharing_my_paranoi...
# 4     2025-12-18_personal_account_sharing_my_paranoi...
# ...                                                 ...
# 1264  2025-12-19_personal_account_content_with_a_cau...
# 1265  2025-12-19_personal_account_content_with_a_cau...
# 1266  2025-12-19_personal_account_content_with_a_cau...
# 1267  2025-12-19_personal_account_content_with_a_cau...
# 1268  2025-12-19_personal_account_content_with_a_cau...
#
#                                                    text group  \
# 0     Last night my internet went down. I tried disc...   scz
# 1     Last night my internet went down. I tried disc...   scz
# 2     Last night my internet went down. I tried disc...   scz
# 3     Last night my internet went down. I tried disc...   scz
# 4     Last night my internet went down. I tried disc...   scz
# ...                                                 ...   ...
# 1264  Five years ago, I faced one of the toughest de...    hc
# 1265  Five years ago, I faced one of the toughest de...    hc
# 1266  Five years ago, I faced one of the toughest de...    hc
# 1267  Five years ago, I faced one of the toughest de...    hc
# 1268  Five years ago, I faced one of the toughest de...    hc
#
#                                             list_tokens  \
# 0     [night, internet, went, tried, disconnecting, ...
# 1     [night, internet, went, tried, disconnecting, ...
# 2     [night, internet, went, tried, disconnecting, ...
# 3     [night, internet, went, tried, disconnecting, ...
# 4     [night, internet, went, tried, disconnecting, ...
# ...                                                 ...
# 1264  [years, ago, faced, toughest, decisions, life,...
# 1265  [years, ago, faced, toughest, decisions, life,...
# 1266  [years, ago, faced, toughest, decisions, life,...
# 1267  [years, ago, faced, toughest, decisions, life,...
# 1268  [years, ago, faced, toughest, decisions, life,...
#
#                                           list_of_cunks
# 0     [night, internet, went, tried, disconnecting, ...
# 1     [schizo-, phrenia, entered, mind, acquaintance...
# 2     [hacking, computer, messing, internet, entered...
# 3     [prove, schizophrenia, control, suddenly, pops...
# 4     [thoughts, paranoia, ordeal, internet, called,...
# ...                                                 ...
# 1264  [medication, helped, stabilize, moods, allowin...
# 1265  [enabled, function, thrive, personal, life, pr...
# 1266  [forward, work, love, advocating, PiZetta, Med...
# 1267  [connections, empowering, voices, fostering, w...
# 1268  [supported, aspect, life, long, journey, given...
#
# [1269 rows x 5 columns]

# %%
df_exploded.to_parquet("tabelle.parquet")

# %%
text = df.iloc[1,3]

# %%
len(text)
# Out:
# 525

# %%
text
# Out:
# ['schizoaffective',
#  'disorder',
#  'episodes',
#  'obsessive',
#  'behaviors',
#  'detrimental',
#  'health',
#  'obsessively',
#  'cleaning',
#  'every\xad',
#  'thing',
#  'owned',
#  'possibly',
#  'repeatedly',
#  'emptied',
#  'room',
#  'cleaned',
#  'single',
#  'thing',
#  'owned',
#  'including',
#  'room',
#  'scrubbed',
#  'ceilings',
#  'walls',
#  'windows',
#  'hired',
#  'carpet',
#  'cleaner',
#  'professionally',
#  'clean',
#  'carpet',
#  'twice',
#  'cleaned',
#  'hands',
#  'repetitively',
#  'thoroughly',
#  'tons',
#  'little',
#  'cuts',
#  'looked',
#  'run',
#  'buckets',
#  'glass',
#  'shards',
#  'germaphobe',
#  'believed',
#  'messiah',
#  'thought',
#  'external',
#  'purity',
#  'created',
#  'internal',
#  'purity',
#  'save',
#  'world',
#  'needed',
#  'pure',
#  'Immediately',
#  'second',
#  'episode',
#  'germ\xad',
#  'aphobe',
#  'Overcoming',
#  'abnormal',
#  'fear',
#  'germs',
#  'took',
#  'mental',
#  'flexibility',
#  'worked',
#  'doctor',
#  'talk',
#  'therapy',
#  'searched',
#  'reasons',
#  'abnormal',
#  'fear',
#  'eventually',
#  'disclosed',
#  'thought',
#  'messiah',
#  'correctly',
#  'pure',
#  'person',
#  'couple',
#  'years',
#  'stopped',
#  'obsessively',
#  'hand',
#  'washing',
#  'uncovered',
#  'deeper',
#  'reasons',
#  'hand',
#  'washing',
#  'came',
#  'wanting',
#  'con\xad',
#  'trol',
#  'life',
#  'schizoaffective',
#  'disorder',
#  'epi\xad',
#  'sode',
#  'disorienting',
#  'precarious',
#  'felt',
#  'control',
#  'material',
#  'possessions',
#  'clean',
#  'mind',
#  'cleaner',
#  'able',
#  'think',
#  'clearly',
#  'control',
#  'took',
#  'time',
#  'face',
#  'fears',
#  'generated',
#  'hand',
#  'washing',
#  'determined',
#  'reasons',
#  'excessively',
#  'washing',
#  'afraid',
#  'refrain',
#  'occurred',
#  'difficulty',
#  'trust\xad',
#  'ing',
#  'logic',
#  'presenting',
#  'case',
#  'understood',
#  'surface',
#  'logic',
#  'lis\xad',
#  'emotional',
#  'connections',
#  'irrational',
#  'subconscious',
#  'fears',
#  'connected',
#  'obsessive',
#  'habits',
#  'facet',
#  'comes',
#  'play',
#  'understanding',
#  'deeper',
#  'logic',
#  'psyche',
#  'time',
#  'able',
#  'delve',
#  'deep',
#  'mind',
#  'understand',
#  'way',
#  'thinking',
#  'obsessive',
#  'compulsions',
#  'occurring',
#  'Having',
#  'current',
#  'ability',
#  'helped',
#  'overcome',
#  'issues',
#  'know',
#  'deepest',
#  'reasons',
#  'obses\xad',
#  'sively',
#  'washed',
#  'having',
#  'basic',
#  'logic',
#  'understand',
#  'habit',
#  'helped',
#  'exposing',
#  'washing',
#  'hands',
#  'times',
#  'irrational',
#  'fear',
#  'found',
#  'dozens',
#  'questions',
#  'doubts',
#  'opposing',
#  'change',
#  'habit',
#  'answer',
#  'questions',
#  'refute',
#  'doubts',
#  'having',
#  'courage',
#  'face',
#  'eliminate',
#  'fear',
#  'breaking',
#  'compulsive',
#  'habits',
#  'trying',
#  'new',
#  'way',
#  'things',
#  'facing',
#  'compulsive',
#  'hand',
#  'washing',
#  'worried',
#  'washing',
#  'hands',
#  'coming',
#  'contact',
#  'disre\xad',
#  'spectful',
#  'health',
#  'diminish',
#  'wash',
#  'hands',
#  'thoroughly',
#  'frequently',
#  'Talk',
#  'therapy',
#  'journaling',
#  'extremely',
#  'helpful',
#  'eliminating',
#  'questions',
#  'doubts',
#  'nature',
#  'earlier',
#  'stages',
#  'recovery',
#  'needed',
#  'talk',
#  'therapy',
#  'guide',
#  'doctor',
#  'help',
#  'refute',
#  'questions',
#  'mental',
#  'health',
#  'intelligence',
#  'improved',
#  'able',
#  'frequently',
#  'eliminate',
#  'questions',
#  'journaling',
#  'able',
#  'better',
#  'understand',
#  'reasons',
#  'afraid',
#  'experience',
#  'given',
#  'courage',
#  'face',
#  'fear',
#  'point',
#  'hands',
#  'cut',
#  'pain',
#  'knew',
#  'messiah',
#  'anymore',
#  'washed',
#  'doctor',
#  'recommended',
#  'exposure',
#  'therapy',
#  'exposed',
#  'washing',
#  'dealt',
#  'emotions',
#  'experience',
#  'hand',
#  'anxiety',
#  'extremely',
#  'high',
#  'couple',
#  'times',
#  'wash\xad',
#  'ing',
#  'hands',
#  'excessively',
#  'compulsions',
#  'return',
#  'washing',
#  'kept',
#  'disciplined',
#  'avoided',
#  'Seeing',
#  'example',
#  'previously',
#  'overcame',
#  'fear',
#  'context',
#  'life',
#  'extremely',
#  'helpful',
#  'important',
#  'context',
#  'life',
#  'empirical',
#  'knowledge',
#  'corroborate',
#  'ideas',
#  'doctor',
#  'impressing',
#  'hand',
#  'expe\xad',
#  'rience',
#  'refuted',
#  'questions',
#  'pose',
#  'life',
#  'simply',
#  'held',
#  'true',
#  'exposed',
#  'fear',
#  'felt',
#  'increasingly',
#  'safer',
#  'knew',
#  'right',
#  'refraining',
#  'excessive',
#  'washing',
#  'nagging',
#  'urge',
#  'wash',
#  'felt',
#  'anxiety',
#  'fought',
#  'times',
#  'washing',
#  'hands',
#  'excessively',
#  'felt',
#  'terrifying',
#  'realized',
#  'anxiety',
#  'coming',
#  'issues',
#  'life',
#  'thought',
#  'refraining',
#  'washing',
#  'idea',
#  'helped',
#  'completely',
#  'dis\xad',
#  'miss',
#  'delusion',
#  'speaks',
#  'volumes',
#  'number',
#  'issues',
#  'people',
#  'mental',
#  'illness',
#  'constantly',
#  'face',
#  'having',
#  'experienced',
#  'episodes',
#  'realizing',
#  'anxiety',
#  'issues',
#  'excessive',
#  'hand',
#  'washing',
#  'urge',
#  'excessively',
#  'wash',
#  'completely',
#  'eliminated',
#  'Adverse',
#  'emotions',
#  'hovered',
#  'obsessive',
#  'behav\xad',
#  'iors',
#  'episodes',
#  'simply',
#  'reminded',
#  'episode',
#  'dissipated',
#  'time',
#  'meaning',
#  'surrounding',
#  'behaviors',
#  'changed',
#  'moved',
#  'away',
#  'episode',
#  'health\xad',
#  'ier',
#  'wanted',
#  'clean',
#  'hands',
#  'rational',
#  'mind',
#  'decided',
#  'instances',
#  'use',
#  'water',
#  'use',
#  'soap',
#  'water',
#  'realized',
#  'comes',
#  'obsessive',
#  'behaviors',
#  'simply',
#  'identify',
#  'purpose',
#  'behavior',
#  'fulfill',
#  'purpose',
#  'fulfilled',
#  'different',
#  'task',
#  'understand',
#  'mes\xad',
#  'siah',
#  'need',
#  'purify',
#  'safeguard',
#  'place',
#  'obsessive',
#  'cleaning',
#  'told',
#  'certain',
#  'dirt',
#  'remain',
#  'earth',
#  'time',
#  'time',
#  'exhaust',
#  'natural',
#  'resources',
#  'excessively',
#  'cleaning',
#  'cur\xad',
#  'rently',
#  'understand',
#  'miss',
#  'hand',
#  'washing',
#  'negative',
#  'repercussions',
#  'fairly',
#  'certain',
#  'world',
#  'going',
#  'run',
#  'resources',
#  'cleaning',
#  'know',
#  'think',
#  'differently',
#  'episodes',
#  'think',
#  'OCD',
#  'problem',
#  'safeguards',
#  'nature',
#  'place',
#  'case',
#  'episode',
#  'facing',
#  'new',
#  'fears',
#  'preparing',
#  'exposed',
#  'remember',
#  'times',
#  'pre\xad',
#  'viously',
#  'exposed',
#  'thing',
#  'experience',
#  'afraid',
#  'rendered',
#  'negative',
#  'repercussions',
#  'posi\xad',
#  'tive',
#  'outcome',
#  'given',
#  'courage',
#  'face',
#  'fears',
#  'undergo',
#  'exposure',
#  'therapy',
#  'positive',
#  'memories',
#  'completely',
#  'eliminated',
#  'fear',
#  'altogether',
#  'void',
#  'anxiety',
#  'nega\xad',
#  'tive',
#  'emotions',
#  'facing',
#  'experience',
#  'afraid']

# %%
for element in text:
    print(element)
# Out:
# schizoaffective
# disorder
# episodes
# obsessive
# behaviors
# detrimental
# health
# obsessively
# cleaning
# every­
# thing
# owned
# possibly
# repeatedly
# emptied
# room
# cleaned
# single
# thing
# owned
# including
# room
# scrubbed
# ceilings
# walls
# windows
# hired
# carpet
# cleaner
# professionally
# clean
# carpet
# twice
# cleaned
# hands
# repetitively
# thoroughly
# tons
# little
# cuts
# looked
# run
# buckets
# glass
# shards
# germaphobe
# believed
# messiah
# thought
# external
# purity
# created
# internal
# purity
# save
# world
# needed
# pure
# Immediately
# second
# episode
# germ­
# aphobe
# Overcoming
# abnormal
# fear
# germs
# took
# mental
# flexibility
# worked
# doctor
# talk
# therapy
# searched
# reasons
# abnormal
# fear
# eventually
# disclosed
# thought
# messiah
# correctly
# pure
# person
# couple
# years
# stopped
# obsessively
# hand
# washing
# uncovered
# deeper
# reasons
# hand
# washing
# came
# wanting
# con­
# trol
# life
# schizoaffective
# disorder
# epi­
# sode
# disorienting
# precarious
# felt
# control
# material
# possessions
# clean
# mind
# cleaner
# able
# think
# clearly
# control
# took
# time
# face
# fears
# generated
# hand
# washing
# determined
# reasons
# excessively
# washing
# afraid
# refrain
# occurred
# difficulty
# trust­
# ing
# logic
# presenting
# case
# understood
# surface
# logic
# lis­
# emotional
# connections
# irrational
# subconscious
# fears
# connected
# obsessive
# habits
# facet
# comes
# play
# understanding
# deeper
# logic
# psyche
# time
# able
# delve
# deep
# mind
# understand
# way
# thinking
# obsessive
# compulsions
# occurring
# Having
# current
# ability
# helped
# overcome
# issues
# know
# deepest
# reasons
# obses­
# sively
# washed
# having
# basic
# logic
# understand
# habit
# helped
# exposing
# washing
# hands
# times
# irrational
# fear
# found
# dozens
# questions
# doubts
# opposing
# change
# habit
# answer
# questions
# refute
# doubts
# having
# courage
# face
# eliminate
# fear
# breaking
# compulsive
# habits
# trying
# new
# way
# things
# facing
# compulsive
# hand
# washing
# worried
# washing
# hands
# coming
# contact
# disre­
# spectful
# health
# diminish
# wash
# hands
# thoroughly
# frequently
# Talk
# therapy
# journaling
# extremely
# helpful
# eliminating
# questions
# doubts
# nature
# earlier
# stages
# recovery
# needed
# talk
# therapy
# guide
# doctor
# help
# refute
# questions
# mental
# health
# intelligence
# improved
# able
# frequently
# eliminate
# questions
# journaling
# able
# better
# understand
# reasons
# afraid
# experience
# given
# courage
# face
# fear
# point
# hands
# cut
# pain
# knew
# messiah
# anymore
# washed
# doctor
# recommended
# exposure
# therapy
# exposed
# washing
# dealt
# emotions
# experience
# hand
# anxiety
# extremely
# high
# couple
# times
# wash­
# ing
# hands
# excessively
# compulsions
# return
# washing
# kept
# disciplined
# avoided
# Seeing
# example
# previously
# overcame
# fear
# context
# life
# extremely
# helpful
# important
# context
# life
# empirical
# knowledge
# corroborate
# ideas
# doctor
# impressing
# hand
# expe­
# rience
# refuted
# questions
# pose
# life
# simply
# held
# true
# exposed
# fear
# felt
# increasingly
# safer
# knew
# right
# refraining
# excessive
# washing
# nagging
# urge
# wash
# felt
# anxiety
# fought
# times
# washing
# hands
# excessively
# felt
# terrifying
# realized
# anxiety
# coming
# issues
# life
# thought
# refraining
# washing
# idea
# helped
# completely
# dis­
# miss
# delusion
# speaks
# volumes
# number
# issues
# people
# mental
# illness
# constantly
# face
# having
# experienced
# episodes
# realizing
# anxiety
# issues
# excessive
# hand
# washing
# urge
# excessively
# wash
# completely
# eliminated
# Adverse
# emotions
# hovered
# obsessive
# behav­
# iors
# episodes
# simply
# reminded
# episode
# dissipated
# time
# meaning
# surrounding
# behaviors
# changed
# moved
# away
# episode
# health­
# ier
# wanted
# clean
# hands
# rational
# mind
# decided
# instances
# use
# water
# use
# soap
# water
# realized
# comes
# obsessive
# behaviors
# simply
# identify
# purpose
# behavior
# fulfill
# purpose
# fulfilled
# different
# task
# understand
# mes­
# siah
# need
# purify
# safeguard
# place
# obsessive
# cleaning
# told
# certain
# dirt
# remain
# earth
# time
# time
# exhaust
# natural
# resources
# excessively
# cleaning
# cur­
# rently
# understand
# miss
# hand
# washing
# negative
# repercussions
# fairly
# certain
# world
# going
# run
# resources
# cleaning
# know
# think
# differently
# episodes
# think
# OCD
# problem
# safeguards
# nature
# place
# case
# episode
# facing
# new
# fears
# preparing
# exposed
# remember
# times
# pre­
# viously
# exposed
# thing
# experience
# afraid
# rendered
# negative
# repercussions
# posi­
# tive
# outcome
# given
# courage
# face
# fears
# undergo
# exposure
# therapy
# positive
# memories
# completely
# eliminated
# fear
# altogether
# void
# anxiety
# nega­
# tive
# emotions
# facing
# experience
# afraid

# %%
text = " ".join(text)   # combines list into one string
words = text.split()

# %%
sents = [sent.text for sent in model(text).sents]

# %%
sents
# Out:
# ['schizoaffective disorder episodes obsessive behaviors detrimental health obsessively cleaning every\xad thing owned possibly repeatedly emptied room cleaned single thing owned including room scrubbed ceilings walls windows hired carpet cleaner professionally clean carpet twice cleaned hands repetitively thoroughly tons little cuts looked run buckets glass shards germaphobe believed messiah thought external purity created internal purity save world needed pure Immediately second episode',
#  'germ\xad aphobe Overcoming abnormal fear germs took mental flexibility worked doctor talk therapy searched reasons abnormal fear eventually disclosed thought messiah correctly pure person couple years stopped obsessively hand washing uncovered deeper reasons hand washing came wanting con\xad trol life schizoaffective disorder epi\xad sode disorienting precarious felt control material possessions clean mind',
#  'cleaner able think clearly control took time face fears generated hand washing determined reasons excessively washing afraid refrain occurred difficulty trust\xad ing logic presenting case understood surface logic lis\xad emotional connections irrational subconscious fears connected obsessive habits facet comes play understanding deeper logic psyche time able delve deep mind understand way thinking obsessive compulsions occurring Having current ability helped overcome issues know deepest reasons obses\xad sively washed having basic logic understand habit helped exposing washing hands times irrational fear found dozens questions doubts opposing change habit answer questions refute doubts having courage face eliminate fear breaking compulsive habits trying new way things facing compulsive hand washing worried washing hands coming contact disre\xad spectful health diminish wash hands thoroughly frequently',
#  'Talk therapy journaling extremely helpful eliminating questions doubts nature earlier stages recovery needed talk therapy guide doctor help refute questions mental health intelligence improved able frequently eliminate questions journaling able better understand reasons afraid experience given courage face fear point hands cut pain knew messiah anymore washed doctor recommended exposure therapy exposed washing dealt emotions experience hand anxiety extremely high couple times wash\xad ing hands excessively compulsions return washing kept disciplined avoided Seeing example previously overcame fear context life extremely helpful important context life empirical knowledge corroborate ideas doctor impressing hand expe\xad rience refuted questions pose life simply held true exposed fear felt increasingly safer knew right refraining excessive washing nagging urge wash felt anxiety fought times washing hands excessively felt terrifying realized anxiety coming issues life thought refraining washing idea helped completely dis\xad miss delusion speaks volumes number issues people mental illness constantly face having experienced episodes realizing anxiety issues excessive hand washing urge excessively wash completely eliminated Adverse emotions hovered obsessive behav\xad iors episodes simply reminded episode dissipated time meaning surrounding behaviors changed moved away episode health\xad ier wanted clean hands rational mind decided instances use water use soap water realized comes obsessive behaviors simply identify purpose behavior fulfill purpose fulfilled different task understand mes\xad siah need purify safeguard place obsessive cleaning told certain dirt remain earth time time exhaust natural resources excessively cleaning',
#  'cur\xad rently understand miss hand washing negative repercussions fairly certain world going run resources cleaning',
#  'know think differently episodes think OCD problem safeguards nature place case episode facing new fears preparing exposed remember times pre\xad viously exposed thing experience afraid rendered negative repercussions posi\xad tive outcome given courage face fears undergo exposure therapy positive memories completely eliminated fear altogether void anxiety nega\xad tive emotions facing experience afraid']

# %%
import spacy
from spacy.matcher import Matcher
from spacy.tokens import Span


def build_nlp():
    nlp = spacy.load("en_core_web_lg")
    matcher = Matcher(nlp.vocab)

    # 1. symptom onset expressions

    matcher.add(
        "SYMPTOM_ONSET",
        [
            [{"LOWER": "since"}, {"LOWER": {"IN": ["childhood", "infancy", "puberty", "teenage", "teens"]}}],
            [{"LOWER": "since"}, {"LOWER": "i"}, {"LOWER": "was"}, {"IS_DIGIT": True}],
            [{"LOWER": "back"}, {"LOWER": "in"}, {"LOWER": {"IN": ["college", "school", "university", "high", "uni"]}}],
            [{"LOWER": "in"}, {"LOWER": "my"}, {"LOWER": {"IN": ["early", "mid", "late"]}},
             {"LOWER": {"IN": ["teens", "twenties", "thirties"]}}],
        ],
    )

    # 2. episode-level markers

    matcher.add(
        "EPISODE_TEMPORAL",
        [
            [{"LOWER": "last"}, {"LOWER": "episode"}, {"LOWER": "in"}, {"ENT_TYPE": "DATE"}],
            [{"LOWER": "during"}, {"LOWER": "my"},
             {"LOWER": {"IN": ["worst", "last", "previous"]}},
             {"LOWER": {"IN": ["period", "episode"]}}, {"LOWER": "in"}, {"ENT_TYPE": "DATE"}],
        ],
    )

    # 3. treatment-related
    
    matcher.add(
        "TREATMENT_TEMPORAL",
        [
            [{"LOWER": {"IN": ["started", "began", "quit", "stopped"]}},
             {"LOWER": {"IN": ["meds", "medications", "therapy"]}},
             {"LOWER": "in"}, {"ENT_TYPE": "DATE"}],

            [{"LOWER": {"IN": ["hospitalised", "hospitalized"]}},
             {"IS_DIGIT": True}, {"LOWER": {"IN": ["years", "months", "weeks"]}},
             {"LOWER": "ago"}],
        ],
    )


    # 4. relapse
    
    matcher.add(
        "RELAPSE_TEMPORAL",
        [
            [{"LOWER": {"IN": ["relapsed", "relapse"]}},
             {"LOWER": "again"}, {"LOWER": {"IN": ["this", "last"]}},
             {"LOWER": {"IN": ["year", "month", "week"]}}],

            [{"LOWER": {"IN": ["episode", "episodes"]}},
             {"LOWER": "last"}, {"LOWER": {"IN": ["month", "year"]}}],
        ],
    )

    # 5. durations (corrected)

    matcher.add(
        "DURATION_TEMPORAL",
        [
            # for six months/for months/for a year
            [
                {"LOWER": "for"},
                {"LOWER": {"IN": ["a", "an"]}, "OP": "?"},
                {"IS_DIGIT": True, "OP": "?"},
                {"LOWER": {"IN": ["day", "days", "week", "weeks", "month",
                                   "months", "year", "years", "decade"]}}
            ],

            # past few months
            [
                {"LOWER": "past"},
                {"LOWER": {"IN": ["few", "couple", "several"]}},
                {"LOWER": {"IN": ["days", "weeks", "months", "years"]}}
            ]
        ],
    )

    # 6. life-event anchors

    matcher.add(
        "LIFE_EVENT_TEMPORAL",
        [
            [{"LOWER": {"IN": ["after", "before", "around", "during"]}},
             {"LOWER": {"IN": ["the", "my"]}, "OP": "?"},
             {"LOWER": {"IN": [
                 "divorce", "breakup", "accident", "pregnancy", "diagnosis",
                 "hospitalisation", "hospitalization", "finals", "lockdown"
             ]}}],
        ],
    )

    # 7. calendar markers

    seasons = ["spring", "summer", "autumn", "fall", "winter"]
    holidays = ["christmas", "easter", "ramadan", "new", "new-year", "new year"]

    matcher.add(
        "CALENDAR_TEMPORAL",
        [
            [{"LOWER": {"IN": ["this", "last"]}}, {"LOWER": {"IN": seasons}}],
            [{"LOWER": {"IN": ["this", "last"]}}, {"LOWER": {"IN": holidays}}],
            [{"LOWER": {"IN": ["earlier", "end"]}}, {"LOWER": "this"},
             {"LOWER": {"IN": ["week", "month", "year"]}}],
        ],
    )

    # 8. vague expressions
    
    matcher.add(
        "VAGUE_TEMPORAL",
        [
            [{"LOWER": "a"}, {"LOWER": "while"}, {"LOWER": "ago"}],
            [{"LOWER": "ages"}, {"LOWER": "ago"}],
            [{"LOWER": "the"}, {"LOWER": "other"}, {"LOWER": "day"}],
            [{"LOWER": "recently"}],
        ],
    )

    # 9. numeric date formats
    
    matcher.add(
        "NUMERIC_DATE",
        [
            # 12/2020, 05/21
            [{"SHAPE": "dd"}, {"TEXT": "/"}, {"SHAPE": {"IN": ["dd", "dddd"]}}],
            # 12.05.2020
            [{"SHAPE": "dd"}, {"TEXT": "."}, {"SHAPE": "dd"},
             {"TEXT": ".", "OP": "?"}, {"SHAPE": "dddd", "OP": "?"}],
            # 2020–21, 2019/2020
            [{"SHAPE": "dddd"}, {"TEXT": {"IN": ["–", "-", "/"]}}, {"SHAPE": {"IN": ["dd", "dddd"]}}],
        ],
    )

    # 10. diagnosis + date
    
    matcher.add(
        "DIAGNOSIS_DATE",
        [
            [{"LOWER": {"IN": ["diagnosed", "dx"]}}, {"LOWER": "in"}, {"ENT_TYPE": "DATE"}],
            [{"LOWER": {"IN": ["diagnosed", "dx"]}}, {"IS_DIGIT": True}],  # diagnosed at 14
            [{"LOWER": {"IN": ["got", "received"]}}, {"LOWER": "my"},
             {"LOWER": "diagnosis"}, {"LOWER": "in"}, {"ENT_TYPE": "DATE"}],
        ],
    )

    nlp.matcher = matcher
    return nlp


def extract_time_spans(text, nlp):
    doc = nlp(text)
    spans = []

    # built-in DATE entities

    for ent in doc.ents:
        if ent.label_ == "DATE":
            spans.append(ent.text)

    # rule-based matches

    for match_id, start, end in nlp.matcher(doc):
        spans.append(doc[start:end].text)

    # dedupe and preserve order
    
    seen = set()
    final = []
    for s in spans:
        if s not in seen:
            seen.add(s)
            final.append(s)

    return final


if __name__ == "__main__":
    nlp = build_nlp()

    text = """
    I was diagnosed in 2018 after the accident.
    Symptoms have been there since childhood and got worse last winter.
    I relapsed again this year after quitting meds two months ago.
    Started therapy in June. Hospitalised three years ago.
    Had another episode last month and during lockdown things escalated.
    I struggled for six months before the diagnosis.
    
    """

    print(extract_time_spans(text, nlp))
# Out:
# ['2018', 'last winter', 'this year', 'two months ago', 'June', 'three years ago', 'last month', 'six months', 'diagnosed in 2018', 'after the accident', 'since childhood', 'relapsed again this year', 'Started therapy in June', 'episode last month', 'during lockdown', 'before the diagnosis']
