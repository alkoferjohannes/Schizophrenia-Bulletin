# %%
from pathlib import Path
from datetime import datetime

# %%
OUTPUT_DIR = Path("/output/path")
 
TITLE = "Personal account: Title of Post"
SOURCE = "Published in Journal Name by Author Name"
TAGS = ["tag to find comparable texts"]  #p.ex. account of everyday experience

#paste the text here

TEXT_CONTENT = """
dummy text
"""

#file creation

timestamp = datetime.now().strftime("%Y-%m-%d")
safe_title = TITLE.lower().replace(" ", "_")

filename = f"{timestamp}_{safe_title}.txt"
output_path = OUTPUT_DIR / filename

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

with open(output_path, "w", encoding="utf-8") as f:
    f.write(f"Title: {TITLE}\n")
    f.write(f"Source: {SOURCE}\n")
    f.write(f"Tags: {', '.join(TAGS)}\n")
    f.write(f"Created: {timestamp}\n")
    f.write("\n" + "=" * 50 + "\n\n")
    f.write(TEXT_CONTENT.strip())

print(f"Saved to: {output_path}")
# Out:
# Saved to: /Users/johannesalkofer/Downloads/pdf_to_text/output_txt/2025-12-18_personal_account:_bad_day.txt
